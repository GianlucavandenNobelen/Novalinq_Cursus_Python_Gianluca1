# %% [markdown]
# # Visualisatie met Python

# %% [markdown]
# <div style="float: left; margin-left: 200px">
#             <img src="files/cpQuote.png" width="500">
#                                                        </div>

# %% [markdown]
# https://towardsdatascience.com/plotly-founder-on-what-data-science-is-and-where-its-going-46c5d6ec6a7d

# %% [markdown]
# # Korte inhoud
#
#   ##   - Functional P / Procedural P / OOP /
#
#   ##   - Matplotlib
#
#   ##   - Seaborn

# %% [markdown]
# # Procedural programmeren/ Procedural programming
#
#   Functional programming is de naam voor een programmeer-methode.
#   Een paradigma dus.
#
#   De organisatie van de logica in het script draait als een recept van boven naar beneden.
#
#   Met elke functie als apart <em>schakeltje</em> in de richting van de output.

# %% [markdown]
# # Functioneel programmeren/ Functional programming
#
#   Functional programming is de naam voor een programmeer-methode.
#   Een paradigma dus.
#
#   Alles draait om de <strong>puurheid</strong> van de executie.
#   <strong>Functies</strong> en <strong>data</strong> worden volledig gescheiden.
#
#   De <strong>uitkomst</strong> van een functie is zo dus afhankelijk van de <strong>input.</strong>

# %% [markdown]
# # Object georienteerd programmeren/ Object Oriented programming
#
#   Object Oriented programming of OOP (for short) is de naam voor een programmeer-methode.
#   Een paradigma dus.
#
#   OOP is handig handig voor reproduceerbare code en zie je vaker bij development-werk
#
#   Je behandeld de data-behandelingen met objecten die je schrijft en aanroept.
#   In de objecten zitten <strong>attributes</strong> en <strong>methods</strong>
#
#   Attributes:
#   Parameters, aan te passen in the fly.
#
#   Methods:
#   Functie-toebehoren van het object.
#
#   Natuurlijk blijven dit schakeltjes in de grote pipeline,
#   Maar de parameters kunnen onderweg herbruikt en aangepast worden.
#   Hierdoor is de output van een object.method afhenkelijk van beide:
#   - De input
#
#   - De parameters

# %% [markdown]
# # Matplotlib!
#   https://matplotlib.org/3.1.0/api/index.html
#
#   ### We duiken niet te diep in Matplotlib!
#
#   Voor een inkijk in de basis van Matplotlib visualisatie.
#
#   1. We focussen op de basis van pyplot...
#   Hierin behandelen we de verschillende grafieken voor verschillende datatypes.
#
#   2. Dan behandelen we de object georienteerde manier van plotten.
#   Deze geeft veel directere controle over de stijl en layout.
#
#   3. Vervolgens maken jullie zelf een titanic dashboard
#   En kijken we gezamenlijk naar code-optimalisatie.
#
# Binnen Matplotlib bestaan nog talloze visualisaties mocht je er in geinteresseerd zijn.
# Zelfs het vermogen tot interactieve plots.
# Voor meer informatie daarover kijk op:
#
# https://matplotlib.org/3.1.1/gallery/index.html voorbeeldengallerij
# https://matplotlib.org/3.1.1/users/interactive.html documentatie interactieve plots
#
#   Hierna gaan we door naar Seaborn.

# %% [markdown]
# #### Dependencies importeren

# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt

# %% [markdown]
# #### Magic gebruiken: matplotlib inline
#
#   Hierdoor worden de visualisaties inline getoond.
#   De visualisaties komen <strong>in</strong> het notebook.

# %%
# %matplotlib inline

# %% [markdown]
# ### VoorbeeldData

# %%
x = pd.Series(np.linspace(0, 10, 50), name = 'x')
y = pd.Series(np.sort(np.random.rand(50)), name = 'y')
z = pd.Series([random.randrange(-12, 21) for x in range(0,50)], name='z')
cat = pd.Series([random.randint(1, 3) for x in range(0, 50)], name='cat')

# %%
Latssea = pd.DataFrame([x,y,z,cat]).T

# %% [markdown]
# # Visualisatie in MatplotLib: Functional programming

# %% [markdown]
# ## Pyplot
#
#
#    Pyplot is aan basis visualisatie-class
#    voor functioneel visualiseren.
#    Hierin behandelen wij:
#
#   - Lijnplot
#   - Histogram
#   - Scatterplot
#   - Barchart
#   - Boxplot
#   - piechart

# %% [markdown]
#
# ### Lijnplot
#
# Ter introductie: de lijnplot.
#
# Twee numerieke variabelen tegenover elkaar.

# %%
plt.plot('x', 'y', data=Latssea)
# Out:
# C:\Users\GianlucavandenNobele\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: Second argument 'y' is ambiguous: could be a color spec but is in data; using as data.  Either rename the entry in data or use three arguments to plot.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## Beetje kaal...
#
#   Wie kan vertellen waar dit over gaat?

# %%
Latssea.plot('x','y', color = 'r')
plt.xlabel("Minutes inside")
plt.ylabel("Level of anxiety")
# Out:
# Text(0, 0.5, 'Level of anxiety')

# %%
plt.plot(Latssea['x'],Latssea['y'], 'r')
plt.xlabel("Minutes inside")
plt.ylabel("Level of anxiety")
plt.title("Sharktank")
# Out:
# Text(0.5, 1.0, 'Sharktank')

# %% [markdown]
# ## Opsomming:
#
#   - Matplotlib.pyplot.plot = standaard functie voor lijngrafiek
#
#   - Voor één output, roepen we verschillende functies aan van pyplot
#     <strong>bijvoorbeeld:</strong>
#                                       - Matplotlibpyplot.xlabel
#                                       - Matplotlibpyplot.ylabel
#                                       - Matplotlibpyplot.title
#
#
# ## Vraag:
#       Welke drie verschillende manieren zijn er om data in een plot in te lezen?
#       (zie ook het verschil in bovenstaande outputs)

# %% [markdown]
# # Subplot.
#
#   met subplot() kunnen we meerdere plots maken.
#   Binnen een gedefinieerde tabel.
#
#   Subplot() neemt:
#   - nrows: Nummer van rijen
#   - ncols: Nummer van kollommen
#   - index: Plaats in de tabel

# %%
plt.subplot(1,2,1)
plt.plot(x, y ,color= 'r')
plt.xlabel("Minutes inside")
plt.ylabel("Level of anxiety")
plt.title("Sharktank")
plt.subplot(1,2,2)
plt.plot(x, z, color='g')
plt.xlabel("Minutes inside")
plt.ylabel("Executive Precision")
plt.title("Workbench 5")
# Out:
# Text(0.5, 1.0, 'Workbench 5')

# %%
plt.subplot(1,2,1)
plt.plot(x, y, 'r')
plt.xlabel("Minutes inside")
plt.ylabel("Level of anxiety")
plt.title("Sharktank")
plt.subplot(2,2,4)
plt.plot(x, z, 'b*-', markevery=4)
plt.xlabel("Minutes inside")
plt.ylabel("Executive Precision")
plt.title("Workbench 5")
plt.tight_layout()

# %% [markdown]
# # Figsize
#   De "figsize" parameter ven de "figure()" functie van "pyplot".
#   Waar is deze voor? Wat zit er in?
#
#   Gebruik de hulp functionaliteit!

# %%
plt.figure?

# %%
plt.plot(Latssea['x'],Latssea['y'], 'r', alpha = 0.2)
plt.xlabel("Minutes inside")
plt.ylabel("Level of anxiety")
plt.title("Sharktank")
# Out:
# Text(0.5, 1.0, 'Sharktank')

# %% [markdown]
# # *args  & **kwargs
#
# Nifty addition, si? transparansii...
#
# \*args en \**kwargs geven de gebruiker van de functie
# de mogelijkheid om vrij argumenten toe te voegen aan een funtie.
#
# <strong>*args</strong> staat losse argumenten toe, zoals strings of waardes.
#
# <strong>**kwargs</strong> geeft een dict mogelijkheid.
#
#   Voor meer informatie over args en kwargs kijk hier:
#   https://www.geeksforgeeks.org/args-kwargs-python/

# %% [markdown]
# # Actie:
#
#   Maak je bekent met de waarden van subplot
#   In een groter canvas
#   Maak de visualisatie ...'your own'...
#   Met de kleur en marker **kwarg mogelijkheden van plot()
#
#
#
#    ### Kleuren en Markers
#   Bekijk de standaard Matplotlib kleur en marker specificaties.
#
#     Welke kleurnotaties neemt matplotlib?
#   https://matplotlib.org/api/colors_api.html#module-matplotlib.colors
#
#     En hieronder een oversicht van de verschillende markernotaties
#   https://matplotlib.org/api/markers_api.html

# %%
plt.subplot(2,2,1)
plt.plot('x', 'y', 'r')
plt.xlabel("Minutes fleeing")
plt.ylabel("Distance gained by shark")
plt.title("Shark-human")

plt.subplot(2,2,2)
plt.plot(Latssea['x'], Latssea['y'], 'r', alpha = 0.4)
plt.xlabel("Time")
plt.ylabel("Bananas picked")
plt.title("Monkey speed")

plt.subplot(2,2,3)
plt.plot('x', 'y', 'tab:blue', marker='+', markersize=20, markeredgecolor='red', markevery=4)
plt.xlabel('Puzzles solved')
plt.ylabel('eye scanning speed')
plt.title('Eye-to-brain speed in kids')

plt.tight_layout()

# %% [markdown]
# # Styling.

# %%
hfont = {'fontname':'Impact'}
plt.rcParams["font.family"] = "Castellar"
plt.figure(figsize=(10,10), dpi=100)
plt.subplot(3,3,9)
plt.plot(x, y, 'tab:blue', marker='+', markersize=20, markeredgecolor='red', markevery=4)
plt.xlabel("Minutes inside", **hfont)
plt.ylabel("Level of anxiety")
plt.title("Sharktank")
# plt.text(-1,-1, "hahaha", fontsize=26)
# Out:
# Text(0.5, 1.0, 'Sharktank')

# %% [markdown]
# # De kracht van een open source community
#
#
# https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.text.html
# http://jonathansoma.com/lede/data-studio/matplotlib/list-all-fonts-available-in-matplotlib-plus-samples/
# https://matplotlib.org/tutorials/introductory/customizing.html

# %%
import matplotlib.font_manager
from IPython.core.display import HTML

def make_html(fontname):
    return "<p>{font}: <span style='font-family:{font}; font-size: 24px;'>{font}</p>".format(font=fontname)

code = "\n".join([make_html(font) for font in sorted(set([f.name for f in matplotlib.font_manager.fontManager.ttflist]))])

HTML("<div style='column-count: 2;'>{}</div>".format(code))
# Out:
# <div style='column-count: 2;'><p>Agency FB: <span style='font-family:Agency FB; font-size: 24px;'>Agency FB</p>
# <p>Algerian: <span style='font-family:Algerian; font-size: 24px;'>Algerian</p>
# <p>Arial: <span style='font-family:Arial; font-size: 24px;'>Arial</p>
# <p>Arial Rounded MT Bold: <span style='font-family:Arial Rounded MT Bold; font-size: 24px;'>Arial Rounded MT Bold</p>
# <p>Bahnschrift: <span style='font-family:Bahnschrift; font-size: 24px;'>Bahnschrift</p>
# <p>Baskerville Old Face: <span style='font-family:Baskerville Old Face; font-size: 24px;'>Baskerville Old Face</p>
# <p>Bauhaus 93: <span style='font-family:Bauhaus 93; font-size: 24px;'>Bauhaus 93</p>
# <p>Bell MT: <span style='font-family:Bell MT; font-size: 24px;'>Bell MT</p>
# <p>Berlin Sans FB: <span style='font-family:Berlin Sans FB; font-size: 24px;'>Berlin Sans FB</p>
# <p>Berlin Sans FB Demi: <span style='font-family:Berlin Sans FB Demi; font-size: 24px;'>Berlin Sans FB Demi</p>
# ...

# %%
plt.rcParams["font.family"] = "Trebuchet MS"
plt.rcParams["font.size"] = 13
hfont = dict(fontname = 'Impact',
         weight = 'bold',
         size   = 22,
         color = 'red')
cast = {'fontname':'Castellar',
       'size':12}

# %%
plt.rcParams.keys()
# Out:
# C:\Users\GianlucavandenNobele\Anaconda3\lib\_collections_abc.py:705: MatplotlibDeprecationWarning:
# The examples.directory rcparam was deprecated in Matplotlib 3.0 and will be removed in 3.2. In the future, examples will be found relative to the 'datapath' directory.
#   return '{0.__class__.__name__}({0._mapping!r})'.format(self)
# KeysView(RcParams({'_internal.classic_mode': False,
#           'agg.path.chunksize': 0,
#           'animation.avconv_args': [],
#           'animation.avconv_path': 'avconv',
#           'animation.bitrate': -1,
#           'animation.codec': 'h264',
#           'animation.convert_args': [],
#           'animation.convert_path': 'convert',
#           'animation.embed_limit': 20.0,
#           'animation.ffmpeg_args': [],
#           'animation.ffmpeg_path': 'ffmpeg',
#           'animation.frame_format': 'png',
#           'animation.html': 'none',
#           'animation.html_args': [],
#           'animation.writer': 'ffmpeg',
# ...

# %% [markdown]
# # voor meer over stijl...
#
#   https://matplotlib.org/3.2.0/tutorials/introductory/customizing.html

# %% [markdown]
# # Object Oriented visualiseren:
#
#   Maak een object door het aan te roepen en te declareren.
#   Dan methodes en attributes gebruiken.
#
#   - Plaatsing van meerdere visualisaties (op Axes) in 1 canvas (figure).
#   - Algeheel betere controle door plots & canvas als afzonderlijke objecten te behandelen.

# %%
fig = plt.figure(figsize=(5,5), dpi=100)

axes = fig.add_axes([0, 0, 1, 1]) # links, onder, wijdte, hoogte (range 0 tot 1)

axes.plot(x, y, 'b')
axes.set_xlabel('Hoeveelheden aangekocht', **cast) # Notice the use of set_ to begin methods
axes.set_ylabel('x adds bekeken', **cast)
axes.set_title('Manipulation succes', **hfont)

axes1 = fig.add_axes([0.12, 0.55, 0.4, 0.4]) # links, onder, wijdte, hoogte (range 0 tot 1)

axes1.plot(x, z, 'r')
axes1.set_xlabel('Reclame bekeken') # Notice the use of set_ to begin methods
axes1.set_ylabel('enthusiasme merk')
# Out:
# Text(0, 0.5, 'enthusiasme merk')

# %%
axes.plot(x, y, 'g')

# %%
fig

# %% [markdown]
# ### De flexibiliteit van werken met objecten.

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

# %% [markdown]
# Voor meer over tupple unpacking en multiple assignment:
# https://treyhunner.com/2018/03/tuple-unpacking-improves-python-code-readability/

# %%
plt.subplots(nrows=1, ncols=2)
# Out:
# (<Figure size 432x288 with 2 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000027382E14388>,
# ...
#        dtype=object))

# %% [markdown]
# ### Wat is axes nu?

# %%
axes
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000027382C0D688>,
# ...
#       dtype=object)

# %%
for ax in axes:
    ax.plot(x, y, 'b')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_title('title')

# %%
fig

# %%
fig.tight_layout()
fig

# %% [markdown]
# ## Iteration
# Op deze manier kunnen we met een forloop
# Door allerlei waardes van data loopen
# Middels de index
# En gemakkelijk, automatisch zaken visualiseren

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 2, figsize=(10,10)) #sharex=True, sharey=True
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000027382E23D88>,
# ...
#       dtype=object)

# %%
axes[0,0].plot(x,y)
axes[1,0].plot(x,z, 'orange')
axes[0,1].plot(x,y**2, 'green')
axes[1,1].plot(y,z, 'purple')
fig

# %%
fig = plt.figure(figsize=(5,5), dpi=100)

axes = fig.add_axes([0, 0, 1, 1]) # links, onder, wijdte, hoogte (range 0 tot 1)
axes1 = fig.add_axes([0.12, 0.55, 0.4, 0.4]) # links, onder, wijdte, hoogte (range 0 tot 1)

ax1 = axes.plot(x, y,color= 'b')
ax2 = axes.plot(x, (y/2),color= 'g')
axes.set_xlabel('Hoeveelheden aangekocht')
axes.set_ylabel('x adds bekeken')
axes.set_title('Manipulation succes')


axes1.scatter('x', 'z', data=Latssea,color= 'r', s='z')
axes1.set_xlabel('Reclame bekeken')
axes1.set_ylabel('enthusiasme merk')
# Out:
# C:\Users\GianlucavandenNobele\Anaconda3\lib\site-packages\matplotlib\collections.py:857: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# Text(0, 0.5, 'enthusiasme merk')

# %% [markdown]
# # Actie:
#
#
#   Kijk nog eens naar de fantastische grafiek
#   over Manipulatie-succes door adds.
#
#   - Speel met de waardes van de axes.
#   - Kies voor jou passende styling.
#
#   Ga dan naar de documentatiepagina van matplotlib.pyplot.legend()
#   - probeer een legenda toe te voegen aan deze plot.

# %%
fig = plt.figure(figsize=(5,5), dpi=100)

axes = fig.add_axes([0, 0, 1, 1]) # links, onder, wijdte, hoogte (range 0 tot 1)
axes1 = fig.add_axes([0.11, 0.55, 0.4, 0.4]) # links, onder, wijdte, hoogte (range 0 tot 1)

ax1 = axes.plot(x/2, y,color= 'b')
ax2 = axes.plot(x+2, (y/2),color= 'g')
axes.set_xlabel('Hoeveelheden aangekocht')
axes.set_ylabel('x adds bekeken')
axes.set_title('Manipulation succes')


axes1.scatter('x', 'z', data=Latssea,color= 'r')
axes1.set_xlabel('Reclame bekeken')
axes1.set_ylabel('enthusiasme merk')
# Out:
# Text(0, 0.5, 'enthusiasme merk')

# %% [markdown]
# # Histogram
#
#   Handig voor Distributie-indicatie.
#
#   Ook hier kunnen we gebruik maken van:
#
#   - bins
#   - Facecolor
#   - linekleur
#   - aplha
#   - etc etc etc
#
# Bekijk en speel met de parameters van <em>plt.hist</em>
# https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.patches.Patch.html#matplotlib.patches.Patch

# %%
plt.hist(z, bins=18, ec="green", fc="orange", lw=2, ls="--") # <<-- eigen code hier
# Out:
# (array([1., 2., 1., 3., 4., 2., 3., 6., 0., 3., 4., 2., 3., 3., 0., 6., 3.,
#         4.]), array([-12.        , -10.33333333,  -8.66666667,  -7.        ,
#          -5.33333333,  -3.66666667,  -2.        ,  -0.33333333,
#           1.33333333,   3.        ,   4.66666667,   6.33333333,
#           8.        ,   9.66666667,  11.33333333,  13.        ,
#          14.66666667,  16.33333333,  18.        ]), <a list of 18 Patch objects>)

# %%
hist = {"ec":"green", "fc":"orange", "lw":2, "ls":"--"}
plt.hist(z, bins=18,**hist)
# Out:
# (array([1., 2., 1., 3., 4., 2., 3., 6., 0., 3., 4., 2., 3., 3., 0., 6., 3.,
#         4.]), array([-12.        , -10.33333333,  -8.66666667,  -7.        ,
#          -5.33333333,  -3.66666667,  -2.        ,  -0.33333333,
#           1.33333333,   3.        ,   4.66666667,   6.33333333,
#           8.        ,   9.66666667,  11.33333333,  13.        ,
#          14.66666667,  16.33333333,  18.        ]), <a list of 18 Patch objects>)

# %% [markdown]
# ## Piechart
#
#   Bruikbaar voor hoeveelheid voorkomens per categorie.
#
#   Gebruik de help functies:
#   Hoe heeft Piechart graag de koffie?

# %%
plt.pie?

# %% [markdown]
# ### x: array-like, the wedge sizes!

# %% [markdown]
# Cat was onze categorische attribuut.
# Maar de voorkomens per cat zijn nu nog niet geaggregeerd tot één array.
#
# ### Actie:
#
#   Aggregeer de voorkomend per categorie 'cat',
#   tot één Array.
#
#   Zorg dat je ook de juiste categorie-namen in dezelfde volgorde in een array hebt.

# %%
#nunique_cats1 = if Latssea.cat = 1
                    return 1
#nunique_cats2 = if Latssea.cat = 2
                    return 1
#nunique_cats3 = if Latssea.cat = 3
                    return 1

#np.array(object:[[nunique_cats1],[nunique_cats2],[nunique_cats3]])
# Out:
#   File "<ipython-input-31-51fdf04de4c8>", line 1
#     nunique_cats1 = if Latssea.cat = 1
#                      ^
# SyntaxError: invalid syntax

# %%
colors = ['#FF5733', '#FFC300', '#DAF7A6']
labels = np.unique(cat, return_counts=False)

plt.pie(nunique_cats, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=180, colors = colors)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-19071041bce5> in <module>
#       2 labels = np.unique(cat, return_counts=False)
#       3
# ----> 4 plt.pie(nunique_cats, labels=labels,
#       5 autopct='%1.1f%%', shadow=True, startangle=180, colors = colors)
#
# NameError: name 'nunique_cats' is not defined

# %% [markdown]
# ## Boxplot
#
#   De boxplot.
#   Mooie visuale indicatie van de verdeling & dichtheid van onze datapunten.
#
#   van UitschietersMinimum
#   tot uitschieterMaximum:
#   langs minimum (niet-uitschieter),
#   de 3 kwartielen
#   en het maximum(niet uitschieter)

# %%
plt.boxplot([Latssea['x'], Latssea['y'], Latssea['z'], Latssea['cat']], vert=True, whis = 0.2)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x287c86f3588>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x287c8703ec8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x287c8703188>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x287c870ce48>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x287c870cf48>,
# ...
#  'means': []}
# C:\Users\GianlucavandenNobele\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\GianlucavandenNobele\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ## Scatterplot:
#   A dot for evey datapoint.
#   Geeft distributie weer van quantitatieve variabelen.

# %%
plt.scatter(Latssea['x'], Latssea['y'])

# %%
plt.scatter(Latssea['x'], Latssea['y'], c=cat)

# %% [markdown]
# https://matplotlib.org/tutorials/colors/colormaps.html

# %%
plt.scatter(Latssea['x'], Latssea['z'], c=cat)

# %%
plt.scatter(Latssea['x'], Latssea['z'], c=cat, cmap='coolwarm')

# %%
plt.scatter(Latssea['cat'], Latssea['z'], c=cat, cmap='coolwarm')

# %% [markdown]
#   # Opdracht:
#
#   Geef x weer gegroepeerd per categorie 'cat'.
#   In 1 boxplot-plot.
#
#   Onthoud:
#   Boxplot geeft de distributie weer per attribuut.
#   Hoe aggregeren we de data passend?

# %%
X_divby_Cat = Latssea.groupby(cat)

# %%
plt.boxplot(X_divby_Cat, vert=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-8ecd50eeaf66> in <module>
# ----> 1 plt.boxplot(X_divby_Cat, vert=True)
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in boxplot(x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder, data)
#    2477         whiskerprops=whiskerprops, manage_ticks=manage_ticks,
#    2478         autorange=autorange, zorder=zorder, **({"data": data} if data
# -> 2479         is not None else {}))
#    2480
#    2481
#
# ~\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*args, **kwargs)
#     305                 f"for the old name will be dropped %(removal)s.")
# ...

# %% [markdown]
# # OOP vormgeving.
#
#   Ook deze vizzes passen in onze OOP-methode

# %%
fig = plt.figure(figsize=(5,5), dpi=100)

axes = fig.add_axes([0, 0, 1, 1]) # links, onder, wijdte, hoogte (range 0 tot 1)

axes.plot(x, y, 'b')
axes.set_xlabel('Hoeveelheden aangekocht') # Notice the use of set_ to begin methods
axes.set_ylabel('x adds bekeken')
axes.set_title('Manipulation succes')

axes1 = fig.add_axes([0.12, 0.55, 0.4, 0.4]) # links, onder, wijdte, hoogte (range 0 tot 1)

axes1.plot(x, z, 'r')
axes1.set_xlabel('Reclame bekeken') # Notice the use of set_ to begin methods
axes1.set_ylabel('enthusiasme merk')

axes2 = fig.add_axes([1, 0, 1, 1])

axes2.pie(nunique_cats, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=180, colors = colors)
axes2.set_title("Percentages per category")
# Out:
# Text(0.5, 1.0, 'Percentages per category')

# %% [markdown]
# # Actie:
#
#   Importeer de Titanic Dataset.
#   En probeer botvier je nieuwe matplotlib-skills
#
#
#   <strong> Aanpak:</strong>
#   Maak eerst een overzicht met wat subplots in een figure.
#
#   Probeer dan object georienteerd een goede positie te vinden voor Axes.
#   En geef een mooi overzicht over de Titanic-dataset.
#
#   <em>vergeet geen:</em> Labels, Titels, Ticks etc. kleurstelling
#
#       ...Hoe lees je dat ook alweer in?

# %%
Titanic = pd.read_csv("C:\\Users\\GianlucavandenNobele\\OneDrive - RSG Finance B.V\\Documenten\\GitHub\\Novalinq_Cursus_Python_Gianluca1\\RSG Datascience in Python\\RSG Datascience in Python\\3 Visualisatie\\data\\fulltitanic.csv")

# %%
Titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 23 columns):
# Unnamed: 0       1309 non-null int64
# Age              1046 non-null float64
# Cabin            295 non-null object
# Embarked         1307 non-null object
# Fare             1308 non-null float64
# Name             1309 non-null object
# Parch            1309 non-null int64
# PassengerId      1309 non-null int64
# Pclass           1309 non-null int64
# Sex              1309 non-null object
# SibSp            1309 non-null int64
# Survived         891 non-null float64
# Ticket           1309 non-null object
# Title            1309 non-null object
# Age_mean         1309 non-null float64
# Fare_fill        1309 non-null float64
# Embarked_fill    1309 non-null object
# Age_fill         1309 non-null float64
# Cabin_fill       1309 non-null object
# FamilySize       1309 non-null int64
# Family_Single    1309 non-null int64
# Family_Small     1309 non-null int64
# ...

# %%
plt.subplot(1,3,1)
plt.plot(x,y, 'r')
plt.xlabel('Age_fill')
plt.ylabel('Fare_fill')
plt.title('Age to fare')

plt.subplot(1,3,2)
plt.plot(x,y, 'b')
plt.xlabel('Pclass')
plt.ylabel('Parch')
plt.title('Class to children')

plt.subplot(1,3,3)
plt.scatter(Titanic['FamilySize'], Titanic['Age'])
plt.xlabel('FamilySize')
plt.ylabel('Age')
plt.title('Familysize to age')
plt.tight_layout()

# %%
fig = plt.figure(figsize=(5,5), dpi=100)

axes = fig.add_axes([0,0,1,1])

axes.plot('x', 'y', 'r')
axes.set_xlabel('Age_fill')
axes.set_ylabel('Fare_fill')
axes.set_title('Age to fare')
# Out:
# Text(0.5, 1.0, 'Age to fare')

# %% [markdown]
# # Een klein beetje optimalisatie.
#   Voor beter leesbare, beter te bewerken en reproduceerbare code.

# %% [markdown]
# # Actie:
#
#   Kijk naar de herhaaldelijke declaratie van de beschrijvingsfuncties:
#   - legend,
#   - xlabel,
#   - ylabel
#   - enz.
#
#   Schrijf een hulpfuntie die aan het eind <strong>in</strong> de drie hulpfuncties aangeroepen kan worden.

# %% [markdown]
# # Samenvatting
#
#
#   Matplotlib is een stevige, bruikbare standaardbibliotheek.
#   Is motor onder andere paketten, zoals Seaborn.
#
#   Prima bruikbaar voor snelle visualisaties.
#   OOP framework is handig ter controle van vormgeving.
#
#   met:
#   plt.figure()
#   plt.plot()
#   & pie, boxplot, scatter, hist en meer.
#
#   Allright...
#
#   Time for some
#   beautifull seaborn action

# %% [markdown]
# # Visualisatie Deel 2

# %% [markdown]
# ### Nodige import van Titanic

# %%
import pandas as pd
Data = pd.read_csv('data/fulltitanic.csv')
TVis = Data[Data['Survived'].notnull()]

# %% [markdown]
# # Seaborn!
#
# arrrr
#
#   - Ontworpen om naadloos te passen op pandas' DataFrame
#   - Stijlvolle en gebruiksvriendelijke default stijlen
#   - Opensource (dus op Github)
#
#
# https://github.com/mwaskom/seaborn
# https://seaborn.pydata.org/
#
#   Seaborn komt met Standaar datasets.
#   Zichtbaar met sns.get_dataset_names()

# %%
import seaborn as sns

# %% [markdown]
# ## Datasets imports

# %%
sns.get_dataset_names()
# Out:
# C:\Users\GianlucavandenNobele\Anaconda3\lib\site-packages\seaborn\utils.py:376: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 376 of the file C:\Users\GianlucavandenNobele\Anaconda3\lib\site-packages\seaborn\utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)
# ['anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'iris',
#  'mpg',
#  'planets',
#  'tips',
#  'titanic']

# %%
crashes = sns.load_dataset('car_crashes')

# %% [markdown]
# ## Distributieplots

# %% [markdown]
# ### Distplot
#
#   Visualiseer de univariante set observaties
#   De distributie van een kolom
#
#   We gaan kijken naar:
#   <strong>distplot</strong> Distributie van continue variabele
#   <strong>jointplot</strong> Distributie van twee variabelen tegenover elkaar
#   <strong>pairplot </strong> Vergelijk distributie van alle numerieke variabelen
#   <strong>rugplot </strong> Voor precieze plaatsing op x-as van distributies

# %%
sns.distplot(crashes['alcohol'], bins=20)

# %%
sns.jointplot(x='alcohol' , y='total', data=crashes, kind='kde')

# %% [markdown]
# ## Speel de waarde mogelijke parameters van Kind
#
# Hoe veranderd een andere visualisatie het inzicht?

# %%
sns.pairplot(crashes, plot_kws=dict(s=80, edgecolor="white", linewidth=2.5))

# %%
sns.set()

# %% [markdown]
# # Set
#
#   Set, heeft een eental fantastische attributen om de stijl te veranderen.
#   En zoals in veel dependency pakketen kunnen we met <em>kwargs</em> kwasi-arguments
#   Ook waardes veranderen in het onderliggende matplotlib Framework.
#
#    <strong> Speel met de standaardwaarden: </strong>
#     style='darkgrid',
#     palette='deep',
#     font='sans-serif',
#     font_scale=1,
#     color_codes=True,
#     rc=None
#
#    Welke waarden kunnen we nog maar invoeren bij:
#       context='notebook'?
#
#    naslag:
#    https://seaborn.pydata.org/tutorial/aesthetics.html

# %% [markdown]
# ### Palette
#
# Het kiezen van een palette lijkt onbelangrijk, maar het kiezen van de juiste kleuren zegt veel over wat je precies wilt laten zien.

# %%
current_palette = sns.color_palette()
current_palette
# Out:
# [(0.2980392156862745, 0.4470588235294118, 0.6901960784313725),
#  (0.8666666666666667, 0.5176470588235295, 0.3215686274509804),
#  (0.3333333333333333, 0.6588235294117647, 0.40784313725490196),
#  (0.7686274509803922, 0.3058823529411765, 0.3215686274509804),
#  (0.5058823529411764, 0.4470588235294118, 0.7019607843137254),
#  (0.5764705882352941, 0.47058823529411764, 0.3764705882352941),
#  (0.8549019607843137, 0.5450980392156862, 0.7647058823529411),
#  (0.5490196078431373, 0.5490196078431373, 0.5490196078431373),
#  (0.8, 0.7254901960784313, 0.4549019607843137),
#  (0.39215686274509803, 0.7098039215686275, 0.803921568627451)]

# %% [markdown]
# Kleuren zijn gewoon color codes! Als je deze wilt weergeven:

# %%
sns.palplot(current_palette)

# %% [markdown]
# Aanpassen van kleuren met "hsul", welke rekening houdt met gelijke licht en verzadiging distributie.

# %%
sns.palplot(sns.color_palette("husl", 8))

# %% [markdown]
# Of kies zelf je kleurwaardes uit naar believen.

# %%
flatui = ["#9b59b6", "#3498db", "#95a5a6", "#e74c3c", "#34495e", "#2ecc71"]
sns.palplot(sns.color_palette(flatui))

# %% [markdown]
# Wij kiezen nu deze, is het de beste? Discussieer dit tussen elkaar. Wat oogt goed, wat draagt bij aan het inzicht bieden van je data? Vragen die je jezelf altijd moet stellen bij het genereren van plots.

# %%
sns.set(palette='husl', rc={"axes.facecolor": "#967aa0"})

# %%
sns.rugplot(crashes['ins_losses'])
sns.distplot(crashes['ins_losses'])

# %% [markdown]
# ## Titanixercise.
#
#   Gebruik jointplot voor de continue variabelen van TVis
#
#   <strong>tip:</strong>
#   Kijk naar de xlim en ylim variabelen

# %%
#TVis.info()
#sns.jointplot(x='Age', y='Fare', data = TVis)
TVis.rename(columns={"Embarked_fill": "Embarked_max"})
TVis.rename(columns={"Fare_fill": "Fare"})
# Out:
#      Unnamed: 0   Age Cabin Embarked     Fare  \
# 0             0  22.0   NaN        S   7.2500
# 1             1  38.0   C85        C  71.2833
# 2             2  26.0   NaN        S   7.9250
# 3             3  35.0  C123        S  53.1000
# 4             4  35.0   NaN        S   8.0500
# ..          ...   ...   ...      ...      ...
# 886         886  27.0   NaN        S  13.0000
# 887         887  19.0   B42        S  30.0000
# 888         888   NaN   NaN        S  23.4500
# 889         889  26.0  C148        C  30.0000
# 890         890  32.0   NaN        Q   7.7500
#
#                                                   Name  Parch  PassengerId  \
# 0                              Braund, Mr. Owen Harris      0            1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                               Heikkinen, Miss. Laina      0            3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# ...

# %% [markdown]
# ### distributie van categorische waardes

# %%
TVis.keys()
# Out:
# Index(['Unnamed: 0', 'Age', 'Cabin', 'Embarked', 'Fare', 'Name', 'Parch',
#        'PassengerId', 'Pclass', 'Sex', 'SibSp', 'Survived', 'Ticket', 'Title',
#        'Age_mean', 'Fare_fill', 'Embarked_fill', 'Age_fill', 'Cabin_fill',
#        'FamilySize', 'Family_Single', 'Family_Small', 'Family_Large'],
#       dtype='object')

# %%
sns.countplot(x='Title', data= TVis)

# %%
sns.countplot(x='Title', data= TVis, palette='coolwarm')

# %%
sns.countplot(x='Title', data= TVis, hue='Sex', palette='magma')

# %%
sns.barplot(x='Embarked_max', y='Age_mean', hue='Sex', data=TVis, palette='magma')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-789993860676> in <module>
# ----> 1 sns.barplot(x='Embarked_max', y='Age_mean', hue='Sex', data=TVis, palette='magma')
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3147                           estimator, ci, n_boot, units,
#    3148                           orient, color, palette, saturation,
# -> 3149                           errcolor, errwidth, capsize, dodge)
#    3150
#    3151     if ax is None:
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
# ...

# %% [markdown]
# # Hue in pairplot!

# %%
exercise = sns.load_dataset('exercise')
sns.pairplot(exercise, hue='diet')

# %%
sns.pairplot(exercise, hue='diet')
sns.set(palette='coolwarm', rc={"axes.facecolor": "#967aa0"})

# %% [markdown]
# # Boxplot 2.0
#
#   Mooiere, makkelijker plotbare boxplots.
#
#   En supereenvoudige:
#   violin, strip & swarmplots
#
#   Super voor distributie per attribuut of categorie

# %%
sns.boxplot(x='Embarked_max', y='Age_mean', data=TVis)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-7513251f93ab> in <module>
# ----> 1 sns.boxplot(x='Embarked_max', y='Age_mean', data=TVis)
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, notch, ax, **kwargs)
#    2229     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2230                           orient, color, palette, saturation,
# -> 2231                           width, dodge, fliersize, linewidth)
#    2232
#    2233     if ax is None:
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth)
#     444                  width, dodge, fliersize, linewidth):
#     445
# ...

# %%
sns.boxplot(x='Embarked_max', y='Age_mean', data=TVis, hue='Sex')

# %%
sns.violinplot(x='Embarked_max', y='Age_mean', hue='Sex', data=TVis)

# %%
sns.violinplot(x='Embarked_max', y='Age_mean', hue='Sex', data=TVis, split = True)

# %%
sns.violinplot(x='Age_mean', y='Embarked_max', hue='Sex', data=TVis, split = True)

# %%
sns.violinplot(x='Embarked_max', y='Age_mean', hue='Sex', data=TVis)
sns.stripplot(x='Embarked_max', y='Age_mean', hue='Sex', data=TVis, dodge=True, palette='husl' )

# %%
sns.swarmplot(x='Embarked_max', y='Age_mean', hue='Sex', data=TVis, dodge=True)  #color veranderen voor points
# sns.violinplot(x= 'time', y= 'pulse', data=exercise, hue='diet', dodge=True)

# %% [markdown]
# ## Bonus: look at catplot()
#
# Wat doet met de 'kind' paramater?
#
# Options are: “point”, “bar”, “strip”, “swarm”, “box”, “violin”, or “boxen”. Probeer een aantal van deze parameter instelling uit.

# %%
sns.catplot(x= 'Title', y= 'Age_mean', data=TVis, hue='Sex', kind='boxen')

# %% [markdown]
# # Viz-keuze
#
#   Bespreek met manager/collega's/bussiness-user welke plots goed leesbaar zijn.

# %% [markdown]
# # Matrix plots (heatmaps!)
#
#   Voor distibutie-overzicht van grotere variabelen.
#
#   bijvoorbeeld Jaargangen tov maanden
#
#   Data heeft zo een matrix-vorm.
#   Index naam en kolomnaam zijn gelinkt in de cel.

# %%
flights = sns.load_dataset('flights')

# %%
flights.keys()
# Out:
# Index(['year', 'month', 'passengers'], dtype='object')

# %%
fp = flights.pivot_table(index='month', columns='year', values='passengers')

# %%
sns.heatmap(fp)

# %% [markdown]
# # Actie:
#
#   Visualiseer de TitanicData in een heatmap.
#   Welke attributen kunnen we goed tegenover elkaar zetten?
#
#   Welke conclusies kunnen we trekken?
#
#   ### Bekijk de parameters:
#   - annot
#   - cmap
#   - linewidth
#   - linecolor

# %%
#TVis.info()
TVis1 = TVis.pivot_table(index= 'Title', columns= 'FamilySize', values= 'Age')

sns.heatmap(TVis1)

# %% [markdown]
# # o!
#
#   Juist... wat valt ons op aan de heatmap plot?
#
#   https://stackoverflow.com/questions/56942670/matplotlib-seaborn-first-and-last-row-cut-in-half-of-heatmap-plot

# %%
import matplotlib.pyplot as plt

TitanicPivit = TVis.pivot_table(index='Parch', columns='SibSp', values='Age_mean')

ax = sns.heatmap(TitanicPivit, annot=True, square = True)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (7.0, 0.0)

# %%
corr = TVis.corr()
cmap = sns.diverging_palette(220, 10, as_cmap=True) #, center="dark"

plt.figure(figsize=(14, 11))
ax = sns.heatmap(corr, cmap=cmap,vmax=1,linewidths=.6, cbar_kws={"shrink": 0.5})
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (15.0, 0.0)

# %% [markdown]
# # Meer Corr-stylings!
#
#   En meer dan het styleren van je correlatieplot.
#
#   Pandas style functie geeft onwijs veel toffe mogelijkheden
#   Voor het inkleuren van je matrixen, dus ook je dataframes.
#
#   Voor meer styling mogelijkheden, zie:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/style.html

# %%
def color_value(value):

    if (value < 0 and value > -1):
        color = 'red'
    elif (value > 0 and value < 1):
        color = 'green'
    else:
        color = 'black'

    return 'color: %s' % color

# %%
corr.style.applymap(color_value)
# Out:
# <style  type="text/css" >
#     #T_d2c2ade6_7592_11ea_b3ac_380025f586f0row0_col0 {
#             color:  black;
#         }    #T_d2c2ade6_7592_11ea_b3ac_380025f586f0row0_col1 {
#             color:  green;
#         }    #T_d2c2ade6_7592_11ea_b3ac_380025f586f0row0_col2 {
#             color:  green;
#         }    #T_d2c2ade6_7592_11ea_b3ac_380025f586f0row0_col3 {
#             color:  red;
#         }    #T_d2c2ade6_7592_11ea_b3ac_380025f586f0row0_col4 {
#             color:  black;
#         }    #T_d2c2ade6_7592_11ea_b3ac_380025f586f0row0_col5 {
#             color:  red;
#         }    #T_d2c2ade6_7592_11ea_b3ac_380025f586f0row0_col6 {
#             color:  red;
#         }    #T_d2c2ade6_7592_11ea_b3ac_380025f586f0row0_col7 {
#             color:  red;
#         }    #T_d2c2ade6_7592_11ea_b3ac_380025f586f0row0_col8 {
#             color:  green;
#         }    #T_d2c2ade6_7592_11ea_b3ac_380025f586f0row0_col9 {
#             color:  green;
# ...

# %%
corr.style.background_gradient(cmap=cmap)
# Out:
# <style  type="text/css" >
#     #T_4b5e43e4_6eab_11ea_80f3_380025f586f0row0_col0 {
#             background-color:  #da3b46;
#             color:  #f1f1f1;
#         }    #T_4b5e43e4_6eab_11ea_80f3_380025f586f0row0_col1 {
#             background-color:  #aac8d1;
#             color:  #000000;
#         }    #T_4b5e43e4_6eab_11ea_80f3_380025f586f0row0_col2 {
#             background-color:  #c3d8df;
#             color:  #000000;
#         }    #T_4b5e43e4_6eab_11ea_80f3_380025f586f0row0_col3 {
#             background-color:  #c6dae1;
#             color:  #000000;
#         }    #T_4b5e43e4_6eab_11ea_80f3_380025f586f0row0_col4 {
#             background-color:  #da3b46;
#             color:  #f1f1f1;
#         }    #T_4b5e43e4_6eab_11ea_80f3_380025f586f0row0_col5 {
#             background-color:  #b7d1d8;
#             color:  #000000;
#         }    #T_4b5e43e4_6eab_11ea_80f3_380025f586f0row0_col6 {
#             background-color:  #b9d1d9;
#             color:  #000000;
# ...

# %% [markdown]
# # Actie!
#
# Schrijf een functie die zichtbaar maakt wanneer de kans op overleven groter is dan 60 procent in groen en kleiner dan 20% in rood, anders zwart. Groepeer op Pclass en Sex.
#
# Als je alleen wilt conditioneren op bijvoorbeeld `Survived` dan moet je de parameter `subset=['Survived']` toevoegen.

# %%
#TVis.keys()

#TVisgrouped = pd.TVis.groupby('Pclass', 'Sex')
#(waarom vindt die hier 'Sex' niet als variabele bij groupby?)

# Doorrekening vanuit correlaties Survived met Pclass en Sex? Bij survived zelf geeft die namelijk een 0 of een 1 aan.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-6491596d8d4c> in <module>
#       1 #TVis.keys()
#       2
# ----> 3 TVisgrouped = pd.groupby('Pclass', 'Sex')
#       4 #(waarom vindt die hier 'Sex' niet als variabele bij groupby?)
#       5
#
# ~\Anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     212
#     213             return Panel
# --> 214         raise AttributeError("module 'pandas' has no attribute '{}'".format(name))
#     215
#     216
#
# AttributeError: module 'pandas' has no attribute 'groupby'

# %% [markdown]
# # Seaborn op fig.axes
#
#   We kunnen de meeste seaborn plots op matplotlibs axes plaats plotten.
#   Via de ax, parameter.
#   Dit geld helaas niet voor plots die berusten op FacetGrid()...

# %%
fig = plt.figure(figsize=(10,10), dpi=100)

axes = fig.add_axes([0, 0, 1, 0.5])
axes2 = fig.add_axes([0, 0.6, 1, 0.4])

sns.heatmap(fp, ax=axes)
sns.distplot(flights['passengers'], ax=axes2)

# %% [markdown]
# # Functies voor stijl-opties!
#
#   - sns.set_style('white')
#   - sns.set_context('poster',font_scale=4)
#   - sns.set_style('ticks')
#   - sns.despine()

# %% [markdown]
# # Extra
# <strong>Plots voor Verkennende actie</strong>
#
#   Map gebruiken over pairplot & facetgrid
#
#   Hier enkele mooie voorbeelden:
#   https://www.kaggle.com/residentmario/faceting-with-seaborn
#
#   Algemene voorbeelden Seaborn:
#   https://seaborn.pydata.org/examples/index.html

# %%
g = sns.FacetGrid(data=TVis, col='Survived', row='SibSp', size=10)
g.map(sns.countplot, 'Embarked_max', hue=TVis['Sex'])
# Out:
# /usr/local/lib/python3.7/site-packages/seaborn/axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/site-packages/seaborn/axisgrid.py:715: UserWarning: Using the countplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
g = sns.FacetGrid(data=TVis, col='Embarked_max', row='Sex', hue="Title")
g.map(sns.scatterplot, 'Age_mean', 'Title')

# %% [markdown]
# # Lege plot-output?
#
#   Heb je na alle installaties en de initialisatie van de offlinemodus, toch nog issues met plotly?
#
#   Op deze stackoverflow twee handige antwoorden (probeer eerst de trusted versie ;) )
#
#   https://stackoverflow.com/questions/48560138/plotly-offline-iplot-gives-a-large-blank-field-as-its-output-in-jupyter-notebook
